# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("OnlineNewsPopularity.csv")

# %%
data.dtypes
# Out:
# url                                object
#  n_tokens_title                     int64
#  n_tokens_content                   int64
#  n_unique_tokens                  float64
#  n_non_stop_words                 float64
#  n_non_stop_unique_tokens         float64
#  num_hrefs                          int64
#  num_self_hrefs                     int64
#  num_imgs                           int64
#  num_videos                         int64
#  average_token_length             float64
#  num_keywords                       int64
#  data_channel_is_lifestyle          int64
#  data_channel_is_entertainment      int64
#  data_channel_is_bus                int64
#  data_channel_is_socmed             int64
#  data_channel_is_tech               int64
#  data_channel_is_world              int64
#  weekday_is_monday                  int64
#  weekday_is_tuesday                 int64
#  weekday_is_wednesday               int64
#  weekday_is_thursday                int64
# ...

# %%
#data.describe

# %%
data.head(5)
# Out:
#                                                  url   n_tokens_title  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...               12
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...                9
# 2  http://mashable.com/2013/01/07/apple-40-billio...                9
# 3  http://mashable.com/2013/01/07/astronaut-notre...                9
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/               13
#
#     n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0                219          0.663594                1.0
# 1                255          0.604743                1.0
# 2                211          0.575130                1.0
# 3                531          0.503788                1.0
# 4               1072          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  \
# 0                   0.815385           4                2          1
# ...

# %%
data.columns = data.columns.str.strip()

# %%
data['num_hrefs'].unique()
# Out:
# array([  4,   3,   9,  19,   2,  21,  20,  11,   7,  18,  10,  26,  24,
#          1,   5,  22,   8,   0,  27,  25,  14,  15,   6,  17,  32,  23,
#         36,  28,  13,  12,  31,  34,  45,  16,  38,  29,  53,  56,  30,
#         44,  41,  70,  33,  47,  40,  48,  67,  51,  39,  49,  52,  54,
#         42,  59,  57,  43,  63,  50,  35,  46,  37,  71,  69,  64,  62,
#         60,  82, 120, 171,  91,  65, 102,  76,  78,  58,  75,  61, 100,
#         55,  89,  74,  68,  83,  93,  81, 105, 107,  72, 118,  77,  73,
#        117,  79, 140, 127, 122,  86,  85,  96, 152,  98, 101, 116, 110,
#         66,  80, 108,  97, 187, 143, 104,  94, 119, 159, 148, 153, 158,
#        162, 150,  84,  87, 106, 103, 123,  92, 142,  90, 145, 124,  88,
#        161, 186, 304], dtype=int64)

# %%
data['num_hrefs'].isna().sum()
# Out:
# 0

# %%
#to just verify is given data set is clean

# %%
#data_numeric=data.drop(columns=['url'])

# %%
data.describe()
# Out:
#        n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# count    39644.000000      39644.000000     39644.000000      39644.000000
# mean        10.398749        546.514731         0.548216          0.996469
# std          2.114037        471.107508         3.520708          5.231231
# min          2.000000          0.000000         0.000000          0.000000
# 25%          9.000000        246.000000         0.470870          1.000000
# 50%         10.000000        409.000000         0.539226          1.000000
# 75%         12.000000        716.000000         0.608696          1.000000
# max         23.000000       8474.000000       701.000000       1042.000000
#
#        n_non_stop_unique_tokens     num_hrefs  num_self_hrefs      num_imgs  \
# count              39644.000000  39644.000000    39644.000000  39644.000000
# mean                   0.689175     10.883690        3.293638      4.544143
# ...

# %%
"""
we can see for n_tokens_content mean is 546 but max is 8474 
hence we can conclude there are some outliers
smae goes for some other columns aswell
"""
# Out:
# '\nwe can see for n_tokens_content mean is 546 but max is 8474 \nhence we can conclude there are some outliers\nsmae goes for some other columns aswell\n'

# %%
import matplotlib.pyplot as plt

# %%
"""
The 7 weekday columns can be condensed into one column 
while retaining the same information
Same can be done with the data channel columns

"""
# Out:
# '\nThe 7 weekday columns can be condensed into one column \nwhile retaining the same information\nSame can be done with the data channel columns\n\n'

# %%
publishdayMerge=data[['weekday_is_monday','weekday_is_tuesday','weekday_is_wednesday', 
                      'weekday_is_thursday', 'weekday_is_friday','weekday_is_saturday' ,'weekday_is_sunday' ]]
temp_arr=[]
for r in list(range(publishdayMerge.shape[0])):
    for c in list(range(publishdayMerge.shape[1])):
        if ((c==0) and (publishdayMerge.iloc[r,c])==1):
            temp_arr.append('Monday')
        elif ((c==1) and (publishdayMerge.iloc[r,c])==1):
            temp_arr.append('Tueday')
        elif ((c==2) and (publishdayMerge.iloc[r,c])==1):
            temp_arr.append('Wednesday')
        elif ((c==3) and (publishdayMerge.iloc[r,c])==1):
            temp_arr.append('Thursday')
        elif ((c==4) and (publishdayMerge.iloc[r,c])==1):
            temp_arr.append('Friday')
        elif ((c==5) and (publishdayMerge.iloc[r,c])==1):
            temp_arr.append('Saturday') 
        elif ((c==6) and (publishdayMerge.iloc[r,c])==1):
            temp_arr.append('Sunday')
            
# Merging the data channels as one single column
DataChannelMerge=data[['data_channel_is_lifestyle','data_channel_is_entertainment' ,'data_channel_is_bus',
                        'data_channel_is_socmed' ,'data_channel_is_tech','data_channel_is_world' ]]
#logic to merge data channel
DataChannel_arr=[]
for r in list(range(DataChannelMerge.shape[0])):
    if (((DataChannelMerge.iloc[r,0])==0) and ((DataChannelMerge.iloc[r,1])==0) and ((DataChannelMerge.iloc[r,2])==0) and ((DataChannelMerge.iloc[r,3])==0) and ((DataChannelMerge.iloc[r,4])==0) and ((DataChannelMerge.iloc[r,5])==0)):
        DataChannel_arr.append('Others')
    for c in list(range(DataChannelMerge.shape[1])):
        if ((c==0) and (DataChannelMerge.iloc[r,c])==1):
            DataChannel_arr.append('Lifestyle')
        elif ((c==1) and (DataChannelMerge.iloc[r,c])==1):
            DataChannel_arr.append('Entertainment')
        elif ((c==2) and (DataChannelMerge.iloc[r,c])==1):
            DataChannel_arr.append('Business')
        elif ((c==3) and (DataChannelMerge.iloc[r,c])==1):
            DataChannel_arr.append('Social Media')
        elif ((c==4) and (DataChannelMerge.iloc[r,c])==1):
            DataChannel_arr.append('Tech')
        elif ((c==5) and (DataChannelMerge.iloc[r,c])==1):
            DataChannel_arr.append('World')

# %%
"""
Adding this new data to the table and removing the redundant columns
"""
# Out:
# '\nAdding this new data to the table and removing the redundant columns\n'

# %%
data.insert(loc=11, column='weekdays3', value=temp_arr)
data.insert(loc=12, column='data_channel3', value=DataChannel_arr)

data.drop(labels=['data_channel_is_lifestyle','data_channel_is_entertainment' ,'data_channel_is_bus',
                        'data_channel_is_socmed' ,'data_channel_is_tech','data_channel_is_world', 
                 'weekday_is_monday','weekday_is_tuesday','weekday_is_wednesday', 
                      'weekday_is_thursday', 'weekday_is_friday','weekday_is_saturday' ,'weekday_is_sunday'], axis = 1, inplace=True)
print(data.shape)
data.head(n=4)
# Out:
# (39644, 27)
#                                                  url  n_tokens_title  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...              12
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...               9
# 2  http://mashable.com/2013/01/07/apple-40-billio...               9
# 3  http://mashable.com/2013/01/07/astronaut-notre...               9
#
#    n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0               219         0.663594               1.0
# 1               255         0.604743               1.0
# 2               211         0.575130               1.0
# 3               531         0.503788               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# 0                  0.815385          4               2         1           0
# 1                  0.791946          3               1         1           0
# 2                  0.663866          3               1         1           0
# ...

# %%
data.columns
# Out:
# Index(['url', 'n_tokens_title', 'n_tokens_content', 'n_unique_tokens',
#        'n_non_stop_words', 'n_non_stop_unique_tokens', 'num_hrefs',
#        'num_self_hrefs', 'num_imgs', 'num_videos', 'average_token_length',
#        'weekdays3', 'data_channel3', 'num_keywords', 'is_weekend', 'LDA_00',
#        'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_sentiment_polarity',
#        'global_rate_positive_words', 'global_rate_negative_words',
#        'avg_positive_polarity', 'avg_negative_polarity',
#        'title_sentiment_polarity', 'shares'],
#       dtype='object')

# %%
data.head(3)
# Out:
#                                                  url  n_tokens_title  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...              12
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...               9
# 2  http://mashable.com/2013/01/07/apple-40-billio...               9
#
#    n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0               219         0.663594               1.0
# 1               255         0.604743               1.0
# 2               211         0.575130               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# 0                  0.815385          4               2         1           0
# 1                  0.791946          3               1         1           0
# 2                  0.663866          3               1         1           0
#
#    ...    LDA_02    LDA_03    LDA_04  global_sentiment_polarity  \
# 0  ...  0.040005  0.041263  0.040123                   0.092562
# ...

# %%
"""
Data Visualization
"""
# Out:
# '\nData Visualization\n'

# %%
count1=dict(data['shares'].value_counts())
names=count1.keys()
values=count1.values()
fig, axs = plt.subplots(1, 1, figsize=(8, 8), sharey=True)
#axs[0].bar(names, values)
axs.boxplot(names, values)
#axs[2].plot(names, values)
fig.suptitle('Distribution Of Shares')
# Out:
# Text(0.5, 0.98, 'Distribution Of Shares')

# %%
"""
We can observe that the 75th percentile is 2.8K and mean is over 3k which means that the outliers
stronlgy influence the data """
# Out:
# '\nWe can observe that the 75th percentile is 2.8K and mean is over 3k which means that the outliers\nstronlgy influence the data '

# %%
# remove noise from n_tokens_content. those equals to 0
#An article cannot have 0 words
data  = data[data['n_tokens_content'] != 0]
print ("After noise removal - ",data.shape)
# Out:
# After noise removal -  (38463, 27)

# %%
import seaborn as sns

# %%
#Finding relationship between 'rate_positive_words', 'rate_negative_words', 'global_rate_positive_words', 'global_rate_negative_words', and 'shares'
# running a pair plot for the these terms
temp_data = data[data['shares'] <= 100000]
cols1 = [ 'global_rate_positive_words', 'global_rate_negative_words','avg_positive_polarity','avg_negative_polarity', 'shares']
# run a pairplot
sns.pairplot(temp_data, vars=cols1, diag_kind='kde',palette='inferno')

# %%
"""
while most graphs give us almost no information at first glance 
it is safe to conclude that the two near normal average curves can be used for further observation"""
# Out:
# '\nwhile most graphs give us almost no information at first glance \nit is safe to conclude that the two near normal average curves can be used for further observation'

# %%
col2=[ 'n_tokens_title', 'n_tokens_content', 'n_unique_tokens','n_non_stop_words', 'n_non_stop_unique_tokens','shares'] 
col6=[ 'num_hrefs','num_self_hrefs', 'num_imgs', 'num_videos', 'average_token_length','shares']

col3=[  'num_keywords', 'is_weekend','shares']
col4=[ 'LDA_00', 'LDA_01', 'LDA_02', 'LDA_03','LDA_04','shares']
col5=[ 'title_sentiment_polarity','shares']
sns.pairplot(temp_data, vars=col2, diag_kind='auto',palette='inferno')
sns.pairplot(temp_data, vars=col6, diag_kind='auto',palette='inferno')
sns.pairplot(temp_data, vars=col3, diag_kind='auto')
sns.pairplot(temp_data, vars=col4, diag_kind='auto')
sns.pairplot(temp_data, vars=col5, diag_kind='auto')

# %%
"""
The important thing to observe is the final column in all the plots 
observations:
1)n_tokens_title has minimal impact on shares
2)n_tokens_content as no. of tokens significantly increase there is a hige drop off in shares

"""
# Out:
# '\nThe important thing to observe is the final column in all the plots \nobservations:\n1)n_tokens_title has minimal impact on shares\n2)n_tokens_content as no. of tokens significantly increase there is a hige drop off in shares\n\n'

# %%
fig, axes = plt.subplots(figsize=(15,15))
sns.scatterplot(x='title_sentiment_polarity', y='shares', data=temp_data, ax=axes)

# %%
count14=dict(data['weekdays3'].value_counts())
names=count14.keys()
values=count14.values()
fig, axs = plt.subplots(1, 1, figsize=(8, 8), sharey=True)
axs.bar(names, values)
#axs[1].boxplot(names, values)
#axs[2].plot(names, values)
fig.suptitle('Distribution Of Shares by weekday')
# Out:
# Text(0.5, 0.98, 'Distribution Of Shares by weekday')

# %%
#ax = sns.catplot(x='weekdays3', col="shares", data=temp_data, kind="count", height=10, aspect=.7)

# %%
count15=dict(data['data_channel3'].value_counts())
names=count15.keys()
values=count15.values()
fig, axs = plt.subplots(1, 1, figsize=(8, 8), sharey=True)
axs.bar(names, values)
#axs[1].boxplot(names, values)
#axs[2].plot(names, values)
fig.suptitle('Distribution Of Shares by weekday')
# Out:
# Text(0.5, 0.98, 'Distribution Of Shares by weekday')

# %%
#n_tokens_content
sns.scatterplot(x='n_tokens_content',y='shares', data=temp_data)

# %%
"""
n<2000 seems to be ideal
"""
# Out:
# '\nn<2000 seems to be ideal\n'

# %%
sns.scatterplot(x='n_tokens_title',y='shares', data=temp_data)

# %%
"""
6-15 seems to be ideal
"""
# Out:
# '\n6-15 seems to be ideal\n'

# %%
sns.scatterplot(x='num_hrefs',y='shares', data=temp_data)

# %%
#<90

# %%
sns.scatterplot(x='num_imgs',y='shares', data=temp_data)

# %%
from scipy.stats import norm, probplot

#histogram and normal probability plot
temp_data = data[data['shares'] <= 100000]
fig,ax = plt.subplots(figsize=(10,10))
sns.distplot(data['shares'], fit=norm);
fig = plt.figure()
res = probplot(data['shares'], plot=plt)
'''
'Shares' doesn't have a normal distribution. It shows 'peakedness', positive skewness and does not follow the diagonal line.
Thus some statistic analysis might not be suitable for it

'''
# Out:
# "\n'Shares' doesn't have a normal distribution. It shows 'peakedness', positive skewness and does not follow the diagonal line.\nThus some statistic analysis might not be suitable for it\n\n"

# %%
#applying log transformations

# %%
from copy import copy

# %%
#applying log transformation
new_shares_data = copy(data)

new_shares_data.loc[new_shares_data['shares'] > 0, 'shares'] = np.log(data.loc[data['shares'] > 0, 'shares'])
new_shares_log = new_shares_data['shares']
#transformed histogram and normal probability plot
fig,ax = plt.subplots(figsize=(10,10))
sns.distplot(new_shares_log, fit=norm);
fig = plt.figure()
res = probplot(new_shares_log, plot=plt)

# %%
#import pingouin as pg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-60-8d6371489ead> in <module>
# ----> 1 import pingouin as pg
#
# ModuleNotFoundError: No module named 'pingouin'

# %%
data.corr()
# Out:
#                             n_tokens_title  n_tokens_content  n_unique_tokens  \
# n_tokens_title                    1.000000          0.028124        -0.004180
# n_tokens_content                  0.028124          1.000000        -0.010506
# n_unique_tokens                  -0.004180         -0.010506         1.000000
# n_non_stop_words                 -0.003335          0.010961         0.999590
# n_non_stop_unique_tokens         -0.003850         -0.007303         0.999899
# num_hrefs                        -0.047462          0.402893        -0.009077
# num_self_hrefs                   -0.008479          0.283291         0.002565
# num_imgs                         -0.006618          0.353097         0.018767
# num_videos                        0.052470          0.102033        -0.001127
# average_token_length             -0.091570         -0.074420         0.001979
# num_keywords                     -0.008001          0.080738        -0.003000
# ...

# %%
plt.figure(figsize=(10, 10))
corrs = data.corr()
mask = np.zeros_like(corrs)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corrs, cmap='Spectral_r', mask=mask, square=True, vmin=-.4, vmax=.4)
plt.title('Correlation matrix')
plt.tight_layout()

# %%
"""
shares has no high correlation with any on single attribute
"""
# Out:
# '\nshares has no high correlation with any on single attribute\n'
